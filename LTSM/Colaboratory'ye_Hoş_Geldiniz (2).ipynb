# %%
import requests
import pandas as pd
def get_fred_series_observations(series_id, api_key):
    # Endpoint for series observations
    base_url = "https://api.stlouisfed.org/fred/series/observations"
    params = {
        "series_id": series_id,
        "api_key": api_key,
        "file_type": "json"
    }
    response = requests.get(base_url, params=params)
    return response.json()

api_key = 'ef8c3af7f7bebd62ffff5b460d66375a'
series_id = 'CPIAUCSL'

# Fetch the data points for the series
data = get_fred_series_observations(series_id, api_key)

# Check if observations are in the response and create a DataFrame
if 'observations' in data:
    df = pd.DataFrame(data['observations'])
    df = df[['date', 'value']]  # Select only the 'date' and 'value' columns
# Convert 'value' column to float64
df['value'] = df['value'].astype('float64')
df['value'] = (df['value'].pct_change(periods=12) * 100).round(2)  # Calculate percent change
df = df.dropna(subset=['value'])

# %%
# Set the 'year' column as the index
df.set_index('date', inplace=True)
df
# Out:
#             value
# date
# 1948-01-01  10.24
# 1948-02-01   9.48
# 1948-03-01   6.82
# 1948-04-01   8.27
# 1948-05-01   9.38
# ...           ...
# 2023-07-01   3.30
# 2023-08-01   3.71
# 2023-09-01   3.69
# 2023-10-01   3.23
# 2023-11-01   3.12
#
# [911 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Normalize the data: MinMaxScaler
# data_scaled= ( df- df.min()  /( df.max()- df.min())
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df)

# %%
import numpy as np
# Split data into train and test sets
train_size = int(len(data_scaled) * 0.8)
train_data, test_data = data_scaled[:train_size], data_scaled[train_size:]

# Create sequences for LSTM training
def create_sequences(df, seq_length):
    X, y = [], []
    for i in range(len(df) - seq_length):
        X.append(df[i:i+seq_length])
        y.append(df[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 1  # Length of sequences for LSTM
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
'''
# Print the first few elements of each array
print("X_train:", X_train[:5])
print("y_train:", y_train[:5])
print("X_test:", X_test[:5])
print("y_test:", y_test[:5])
# y=x(1)
# Print the shapes of the arrays
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
'''

# %%
from sklearn.model_selection import ParameterGrid
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Define a parameter grid
param_grid = {
    'lstm_units': [20, 50, 100],
    'epochs': [50, 100, 150],
    'batch_size': [16, 32, 64]
}

# Initialize early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

best_mse = float('inf')
best_params = {}

# Iterate over all combinations of parameters
for params in ParameterGrid(param_grid):
    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(units=params['lstm_units'], input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mse')

    # Train the model with early stopping and validation split
    model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], callbacks=[early_stopping], validation_split=0.2)

    # Evaluate the model on the test set
    mse = model.evaluate(X_test, y_test)

    if mse < best_mse:
        best_mse = mse
        best_params = params

# Print the best Mean Squared Error and corresponding parameters
print(f"Best MSE: {best_mse}")
print(f"Best Params: {best_params}")
# Out:
# Epoch 1/50
# 37/37 [==============================] - 4s 17ms/step - loss: 0.1628 - val_loss: 0.0540
# Epoch 2/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0913 - val_loss: 0.0176
# Epoch 3/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0446 - val_loss: 0.0026
# Epoch 4/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0221 - val_loss: 0.0030
# Epoch 5/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0163 - val_loss: 0.0056
# Epoch 6/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0147 - val_loss: 0.0053
# Epoch 7/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0134 - val_loss: 0.0051
# Epoch 8/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.
# 37/37 [==============================] - 0s 4ms/step - loss: 7.3953e-04 - val_loss: 4.7303e-04
# Epoch 22/150
# 37/37 [==============================] - 0s 8ms/step - loss: 7.3490e-04 - val_loss: 4.8563e-04
# Epoch 23/150
# 37/37 [==============================] - 0s 8ms/step - loss: 7.1935e-04 - val_loss: 4.7865e-04
# Epoch 24/150
# 37/37 [==============================] - 0s 8ms/step - loss: 7.1095e-04 - val_loss: 4.8062e-04
# Epoch 25/150
# 37/37 [==============================] - 0s 9ms/step - loss: 7.2588e-04 - val_loss: 4.7023e-04
# Epoch 26/150
# 37/37 [==============================] - 0s 7ms/step - loss: 7.2134e-04 - val_loss: 4.7540e-04
# Epoch 27/150
# 37/37 [==============================] - 0s 6ms/step - loss: 7.2714e-04 - val_loss: 4.8667e-04
# Epoch 28/150
# 37/37 [==============================] - 0s 7ms/step - loss: 7.3173e-04 - val_loss: 4.7338e-04
# Epoch 29/150
# 37/37 [==============================] - 0s 6ms/step - loss: 7.1209e-04 - val_loss: 4.7075e-04
# 6/6 [==============================] - 0s 3ms/step - loss: 7.2217e-04
# Epoch 1/50
# 19/19 [==============================] - 3s 32ms/step - loss: 0.1945 - val_loss: 0.0825
# Epoch 2/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1456 - val_loss: 0.0528
# Epoch 3/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1047 - val_loss: 0.0299
# Epoch 4/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0722 - val_loss: 0.0143
# Epoch 5/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0478 - val_loss: 0.0051
# Epoch 6/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0019
# Epoch 7/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0224 - val_loss: 0.0023
# Epoch 8/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0039
# Epoch 9/50
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0163 - val_loss: 0.0053
# Epoch 10/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0154 - val_loss: 0.0056
# Epoch 11/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0147 - val_loss: 0.0057
# Epoch 12/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0141 - val_loss: 0.0052
# Epoch 13/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0054
# Epoch 14/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0050
# Epoch 15/50
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0046
# Epoch 16/50
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0113 - val_loss: 0.0046
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 1/50
# 19/19 [==============================] - 3s 46ms/step - loss: 0.1488 - val_loss: 0.0526
# Epoch 2/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0896 - val_loss: 0.0207
# Epoch 3/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0468 - val_loss: 0.0043
# Epoch 4/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0018
# Epoch 5/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0147 - val_loss: 0.0046
# Epoch 6/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0130 - val_loss: 0.0055
# Epoch 7/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0049
# Epoch 8/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 0.0047
# Epoch 9/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.0042
# Epoch 10/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0040
# Epoch 11/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0034
# Epoch 12/50
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0030
# Epoch 13/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0026
# Epoch 14/50
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0022
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 1/50
# 19/19 [==============================] - 3s 35ms/step - loss: 0.1639 - val_loss: 0.0495
# Epoch 2/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0830 - val_loss: 0.0120
# Epoch 3/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0345 - val_loss: 0.0017
# Epoch 4/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0173 - val_loss: 0.0061
# Epoch 5/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0149 - val_loss: 0.0068
# Epoch 6/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0054
# Epoch 7/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0045
# Epoch 8/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0044
# Epoch 9/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0099 - val_loss: 0.0043
# Epoch 10/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 0.0033
# Epoch 11/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0031
# Epoch 12/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0028
# Epoch 13/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0021
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 1/100
# 19/19 [==============================] - 3s 45ms/step - loss: 0.1714 - val_loss: 0.0741
# Epoch 2/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1306 - val_loss: 0.0485
# Epoch 3/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0953 - val_loss: 0.0279
# Epoch 4/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0657 - val_loss: 0.0134
# Epoch 5/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0432 - val_loss: 0.0049
# Epoch 6/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0279 - val_loss: 0.0017
# Epoch 7/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0194 - val_loss: 0.0022
# Epoch 8/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0157 - val_loss: 0.0038
# Epoch 9/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0048
# Epoch 10/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0135 - val_loss: 0.0055
# Epoch 11/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0053
# Epoch 12/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0048
# Epoch 13/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0047
# Epoch 14/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0042
# Epoch 15/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0104 - val_loss: 0.0040
# Epoch 16/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0041
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 1/100
# 19/19 [==============================] - 3s 33ms/step - loss: 0.1498 - val_loss: 0.0549
# Epoch 2/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0939 - val_loss: 0.0237
# Epoch 3/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0517 - val_loss: 0.0056
# Epoch 4/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0255 - val_loss: 0.0015
# Epoch 5/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0157 - val_loss: 0.0040
# Epoch 6/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0053
# Epoch 7/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0125 - val_loss: 0.0049
# Epoch 8/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0046
# Epoch 9/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0043
# Epoch 10/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0038
# Epoch 11/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0034
# Epoch 12/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 13/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0032
# Epoch 14/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0027
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 1/100
# 19/19 [==============================] - 3s 34ms/step - loss: 0.1441 - val_loss: 0.0436
# Epoch 2/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0718 - val_loss: 0.0096
# Epoch 3/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0283 - val_loss: 0.0017
# Epoch 4/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0060
# Epoch 5/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0128 - val_loss: 0.0061
# Epoch 6/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0043
# Epoch 7/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0041
# Epoch 8/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0036
# Epoch 9/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 0.0030
# Epoch 10/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0032
# Epoch 11/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 12/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 13/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0019
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 1/150
# 19/19 [==============================] - 3s 33ms/step - loss: 0.1843 - val_loss: 0.0792
# Epoch 2/150
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1424 - val_loss: 0.0528
# Epoch 3/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1062 - val_loss: 0.0310
# Epoch 4/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0752 - val_loss: 0.0147
# Epoch 5/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0501 - val_loss: 0.0049
# Epoch 6/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0330 - val_loss: 0.0018
# Epoch 7/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0233 - val_loss: 0.0029
# Epoch 8/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0194 - val_loss: 0.0052
# Epoch 9/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0180 - val_loss: 0.0064
# Epoch 10/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0171 - val_loss: 0.0067
# Epoch 11/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0163 - val_loss: 0.0066
# Epoch 12/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0155 - val_loss: 0.0061
# Epoch 13/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0057
# Epoch 14/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0138 - val_loss: 0.0056
# Epoch 15/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0051
# Epoch 16/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0047
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0104
# Epoch 1/150
# 19/19 [==============================] - 3s 32ms/step - loss: 0.1707 - val_loss: 0.0633
# Epoch 2/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1097 - val_loss: 0.0295
# Epoch 3/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0638 - val_loss: 0.0090
# Epoch 4/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0338 - val_loss: 0.0018
# Epoch 5/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0198 - val_loss: 0.0032
# Epoch 6/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0155 - val_loss: 0.0059
# Epoch 7/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0065
# Epoch 8/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0053
# Epoch 9/150
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.0045
# Epoch 10/150
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0046
# Epoch 11/150
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0044
# Epoch 12/150
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0037
# Epoch 13/150
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0036
# Epoch 14/150
# 19/19 [==============================] - 0s 8ms/step - loss: 0.
# Epoch 41/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.3031e-04 - val_loss: 4.8439e-04
# Epoch 42/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.2563e-04 - val_loss: 4.7374e-04
# Epoch 43/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.3418e-04 - val_loss: 4.7039e-04
# Epoch 44/150
# 19/19 [==============================] - 0s 6ms/step - loss: 7.3602e-04 - val_loss: 4.8702e-04
# Epoch 45/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.2593e-04 - val_loss: 4.7034e-04
# Epoch 46/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.3036e-04 - val_loss: 4.8891e-04
# Epoch 47/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.2634e-04 - val_loss: 4.7399e-04
# Epoch 48/150
# 19/19 [==============================] - 0s 6ms/step - loss: 7.3338e-04 - val_loss: 4.7470e-04
# Epoch 49/150
# 19/19 [==============================] - 0s 7ms/step - loss: 7.2502e-04 - val_loss: 4.7324e-04
# Epoch 50/150
# 19/19 [==============================] - 0s 6ms/step - loss: 7.2573e-04 - val_loss: 4.7222e-04
# 6/6 [==============================] - 0s 3ms/step - loss: 7.2760e-04
# Epoch 1/50
# 10/10 [==============================] - 4s 97ms/step - loss: 0.1695 - val_loss: 0.0803
# Epoch 2/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1452 - val_loss: 0.0644
# Epoch 3/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1232 - val_loss: 0.0500
# Epoch 4/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1025 - val_loss: 0.0373
# Epoch 5/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0838 - val_loss: 0.0265
# Epoch 6/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0676 - val_loss: 0.0177
# Epoch 7/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0531 - val_loss: 0.0107
# Epoch 8/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0412 - val_loss: 0.0058
# Epoch 9/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0317 - val_loss: 0.0030
# Epoch 10/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0247 - val_loss: 0.0016
# Epoch 11/50
# ...
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0140 - val_loss: 0.0041
# Epoch 15/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0133 - val_loss: 0.0048
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0129 - val_loss: 0.0052
# Epoch 17/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0126 - val_loss: 0.0051
# Epoch 18/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0123 - val_loss: 0.0049
# Epoch 19/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0048
# Epoch 20/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - val_loss: 0.0047
# Epoch 21/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 0.0050
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0104
# Epoch 1/50
# 10/10 [==============================] - 3s 65ms/step - loss: 0.1893 - val_loss: 0.0853
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1535 - val_loss: 0.0626
# Epoch 3/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1216 - val_loss: 0.0431
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0938 - val_loss: 0.0273
# Epoch 5/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0703 - val_loss: 0.0152
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0503 - val_loss: 0.0068
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0353 - val_loss: 0.0026
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0253 - val_loss: 0.0017
# Epoch 9/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0192 - val_loss: 0.0029
# Epoch 10/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0167 - val_loss: 0.0050
# Epoch 11/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0157 - val_loss: 0.0061
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0062
# Epoch 13/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0147 - val_loss: 0.0061
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0142 - val_loss: 0.0057
# Epoch 15/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0137 - val_loss: 0.0060
# Epoch 16/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0132 - val_loss: 0.0058
# Epoch 17/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0055
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0055
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0113
# Epoch 1/50
# 10/10 [==============================] - 3s 92ms/step - loss: 0.1783 - val_loss: 0.0767
# Epoch 2/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1371 - val_loss: 0.0515
# Epoch 3/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1012 - val_loss: 0.0303
# Epoch 4/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0703 - val_loss: 0.0143
# Epoch 5/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0447 - val_loss: 0.0046
# Epoch 6/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0278 - val_loss: 0.0016
# Epoch 7/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0183 - val_loss: 0.0032
# Epoch 8/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0154 - val_loss: 0.0060
# Epoch 9/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0145 - val_loss: 0.0071
# Epoch 10/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0140 - val_loss: 0.0068
# Epoch 11/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0133 - val_loss: 0.0052
# Epoch 12/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0126 - val_loss: 0.0047
# Epoch 13/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0120 - val_loss: 0.0043
# Epoch 14/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0114 - val_loss: 0.0047
# Epoch 15/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0108 - val_loss: 0.0046
# Epoch 16/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0102 - val_loss: 0.0040
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0088
# Epoch 1/100
# 10/10 [==============================] - 3s 65ms/step - loss: 0.1690 - val_loss: 0.0801
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1449 - val_loss: 0.0643
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1229 - val_loss: 0.0502
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1029 - val_loss: 0.0377
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0845 - val_loss: 0.0271
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0685 - val_loss: 0.0184
# Epoch 7/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0543 - val_loss: 0.0116
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0427 - val_loss: 0.0065
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0329 - val_loss: 0.0033
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0018
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0015
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0174 - val_loss: 0.0020
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0154 - val_loss: 0.0029
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - val_loss: 0.0039
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0136 - val_loss: 0.0047
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 0.0050
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0129 - val_loss: 0.0051
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - val_loss: 0.0050
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0048
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0047
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - val_loss: 0.0046
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 1/100
# 10/10 [==============================] - 3s 61ms/step - loss: 0.1900 - val_loss: 0.0846
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1528 - val_loss: 0.0610
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1204 - val_loss: 0.0412
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0916 - val_loss: 0.0255
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0680 - val_loss: 0.0137
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0483 - val_loss: 0.0059
# Epoch 7/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0341 - val_loss: 0.0023
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0248 - val_loss: 0.0018
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0198 - val_loss: 0.0031
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0172 - val_loss: 0.0049
# Epoch 11/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0162 - val_loss: 0.0062
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0156 - val_loss: 0.0066
# Epoch 13/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0151 - val_loss: 0.0061
# Epoch 14/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0145 - val_loss: 0.0058
# Epoch 15/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0140 - val_loss: 0.0058
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0134 - val_loss: 0.0055
# Epoch 17/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0128 - val_loss: 0.0053
# Epoch 18/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0123 - val_loss: 0.0047
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0104
# Epoch 1/100
# 10/10 [==============================] - 3s 63ms/step - loss: 0.1855 - val_loss: 0.0787
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1404 - val_loss: 0.0511
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1016 - val_loss: 0.0290
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0690 - val_loss: 0.0130
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0436 - val_loss: 0.0038
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0017
# Epoch 7/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0186 - val_loss: 0.0038
# Epoch 8/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0158 - val_loss: 0.0064
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0076
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0146 - val_loss: 0.0068
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0139 - val_loss: 0.0058
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0133 - val_loss: 0.0046
# Epoch 13/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0126 - val_loss: 0.0041
# Epoch 14/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 0.0044
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0046
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0106 - val_loss: 0.0046
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 1/150
# 10/10 [==============================] - 3s 61ms/step - loss: 0.1754 - val_loss: 0.0844
# Epoch 2/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1531 - val_loss: 0.0695
# Epoch 3/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1329 - val_loss: 0.0560
# Epoch 4/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1135 - val_loss: 0.0441
# Epoch 5/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0960 - val_loss: 0.0333
# Epoch 6/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0799 - val_loss: 0.0240
# Epoch 7/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0651 - val_loss: 0.0159
# Epoch 8/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0517 - val_loss: 0.0098
# Epoch 9/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0411 - val_loss: 0.0056
# Epoch 10/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0327 - val_loss: 0.0030
# Epoch 11/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0264 - val_loss: 0.0018
# Epoch 12/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0218 - val_loss: 0.0016
# Epoch 13/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0186 - val_loss: 0.0021
# Epoch 14/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0165 - val_loss: 0.0028
# Epoch 15/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0154 - val_loss: 0.0038
# Epoch 16/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0145 - val_loss: 0.0046
# Epoch 17/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0141 - val_loss: 0.0052
# Epoch 18/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0137 - val_loss: 0.0057
# Epoch 19/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0134 - val_loss: 0.0058
# Epoch 20/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0131 - val_loss: 0.0056
# Epoch 21/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0052
# Epoch 22/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0051
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 1/150
# 10/10 [==============================] - 3s 99ms/step - loss: 0.1651 - val_loss: 0.0750
# Epoch 2/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1350 - val_loss: 0.0556
# Epoch 3/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1078 - val_loss: 0.0385
# Epoch 4/150
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0828 - val_loss: 0.0241
# Epoch 5/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0609 - val_loss: 0.0128
# Epoch 6/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0428 - val_loss: 0.0055
# Epoch 7/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0296 - val_loss: 0.0021
# Epoch 8/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0210 - val_loss: 0.0015
# Epoch 9/150
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0164 - val_loss: 0.0027
# Epoch 10/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0044
# Epoch 11/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0133 - val_loss: 0.0058
# Epoch 12/150
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0130 - val_loss: 0.0061
# Epoch 13/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0053
# Epoch 14/150
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0046
# Epoch 15/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0116 - val_loss: 0.0044
# Epoch 16/150
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0111 - val_loss: 0.0042
# Epoch 17/150
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0039
# Epoch 18/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0039
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0087
# Epoch 1/150
# 10/10 [==============================] - 3s 66ms/step - loss: 0.1837 - val_loss: 0.0774
# Epoch 2/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1387 - val_loss: 0.0503
# Epoch 3/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1004 - val_loss: 0.0282
# Epoch 4/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0677 - val_loss: 0.0124
# Epoch 5/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0428 - val_loss: 0.0038
# Epoch 6/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0266 - val_loss: 0.0017
# Epoch 7/150
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0184 - val_loss: 0.0038
# Epoch 8/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0158 - val_loss: 0.0067
# Epoch 9/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0150 - val_loss: 0.0071
# Epoch 10/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0145 - val_loss: 0.0067
# Epoch 11/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0138 - val_loss: 0.0061
# Epoch 12/150
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0131 - val_loss: 0.0050
# Epoch 13/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0049
# Epoch 14/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0043
# Epoch 15/150
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0112 - val_loss: 0.0038
# Epoch 16/150
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0105 - val_loss: 0.0042
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0091
# Best MSE: 0.0007103609386831522
# Best Params: {'batch_size': 16, 'epochs': 50, 'lstm_units': 100}

# %%
# Build and train the LSTM model
# Best MSE: 0.0007103609386831522
# Best params from batch : 16 epochs :150 and units:100
model = Sequential()
model.add(LSTM(units=100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=150, batch_size=16)

# Predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)
# Out:
# Epoch 1/150
# 46/46 [==============================] - 2s 3ms/step - loss: 0.1082
# Epoch 2/150
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0198
# Epoch 3/150
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0128
# Epoch 4/150
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0103
# Epoch 5/150
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 6/150
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0058
# Epoch 7/150
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 8/150
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 9/150
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 10/150
# 46/46 [==============================] - 0s 4ms/step - loss: 9.7282e-04
# Epoch 11/150
# 46/46 [==============================] - 0s 4ms/step - loss: 7.7611e-04
# Epoch 12/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.9927e-04
# Epoch 13/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.8112e-04
# Epoch 14/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7945e-04
# Epoch 15/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7500e-04
# Epoch 16/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7549e-04
# Epoch 17/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7910e-04
# Epoch 18/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7595e-04
# Epoch 19/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7707e-04
# Epoch 20/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.9022e-04
# Epoch 21/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.8140e-04
# Epoch 22/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.8937e-04
# Epoch 23/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.9695e-04
# Epoch 24/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7947e-04
# Epoch 25/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7675e-04
# Epoch 26/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7394e-04
# Epoch 27/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7756e-04
# Epoch 28/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7480e-04
# Epoch 29/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7667e-04
# Epoch 30/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.6427e-04
# Epoch 31/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6990e-04
# Epoch 32/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6418e-04
# Epoch 33/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6982e-04
# Epoch 34/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5609e-04
# Epoch 35/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.6748e-04
# Epoch 36/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7474e-04
# Epoch 37/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5577e-04
# Epoch 38/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.6229e-04
# Epoch 39/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7960e-04
# Epoch 40/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6848e-04
# Epoch 41/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6403e-04
# Epoch 42/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7879e-04
# Epoch 43/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6933e-04
# Epoch 44/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6326e-04
# Epoch 45/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5528e-04
# Epoch 46/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7460e-04
# Epoch 47/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7456e-04
# Epoch 48/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6201e-04
# Epoch 49/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5437e-04
# Epoch 50/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5001e-04
# Epoch 51/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5549e-04
# Epoch 52/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5481e-04
# Epoch 53/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7564e-04
# Epoch 54/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8130e-04
# Epoch 55/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6648e-04
# Epoch 56/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6671e-04
# Epoch 57/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8719e-04
# Epoch 58/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5375e-04
# Epoch 59/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5573e-04
# Epoch 60/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5545e-04
# Epoch 61/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5478e-04
# Epoch 62/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5476e-04
# Epoch 63/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5214e-04
# Epoch 64/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.4950e-04
# Epoch 65/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6275e-04
# Epoch 66/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7052e-04
# Epoch 67/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5223e-04
# Epoch 68/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6303e-04
# Epoch 69/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6079e-04
# Epoch 70/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5961e-04
# Epoch 71/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7719e-04
# Epoch 72/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7278e-04
# Epoch 73/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5840e-04
# Epoch 74/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6460e-04
# Epoch 75/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7965e-04
# Epoch 76/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7084e-04
# Epoch 77/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.6029e-04
# Epoch 78/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7374e-04
# Epoch 79/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7427e-04
# Epoch 80/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6444e-04
# Epoch 81/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5594e-04
# Epoch 82/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5724e-04
# Epoch 83/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.4833e-04
# Epoch 84/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7176e-04
# Epoch 85/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6153e-04
# Epoch 86/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7407e-04
# Epoch 87/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5085e-04
# Epoch 88/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8364e-04
# Epoch 89/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6578e-04
# Epoch 90/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5551e-04
# Epoch 91/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8720e-04
# Epoch 92/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7641e-04
# Epoch 93/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7305e-04
# Epoch 94/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.6056e-04
# Epoch 95/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.6803e-04
# Epoch 96/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.4489e-04
# Epoch 97/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.6188e-04
# Epoch 98/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.5524e-04
# Epoch 99/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.4304e-04
# Epoch 100/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.9536e-04
# Epoch 101/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7591e-04
# Epoch 102/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.5726e-04
# Epoch 103/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.4923e-04
# Epoch 104/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.6322e-04
# Epoch 105/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.6906e-04
# Epoch 106/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.7685e-04
# Epoch 107/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.4578e-04
# Epoch 108/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.5623e-04
# Epoch 109/150
# 46/46 [==============================] - 0s 5ms/step - loss: 6.5990e-04
# Epoch 110/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6051e-04
# Epoch 111/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6830e-04
# Epoch 112/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.4927e-04
# Epoch 113/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.9017e-04
# Epoch 114/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7367e-04
# Epoch 115/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5122e-04
# Epoch 116/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.9263e-04
# Epoch 117/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5062e-04
# Epoch 118/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5116e-04
# Epoch 119/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6320e-04
# Epoch 120/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8399e-04
# Epoch 121/150
# 46/46 [==============================] - 0s 3ms/step - loss: 7.0931e-04
# Epoch 122/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7249e-04
# Epoch 123/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5600e-04
# Epoch 124/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.4275e-04
# Epoch 125/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.9467e-04
# Epoch 126/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6515e-04
# Epoch 127/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5507e-04
# Epoch 128/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.4561e-04
# Epoch 129/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6234e-04
# Epoch 130/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.3936e-04
# Epoch 131/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5356e-04
# Epoch 132/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6749e-04
# Epoch 133/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6287e-04
# Epoch 134/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5835e-04
# Epoch 135/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5936e-04
# Epoch 136/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5667e-04
# Epoch 137/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.6283e-04
# Epoch 138/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6184e-04
# Epoch 139/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.5956e-04
# Epoch 140/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5247e-04
# Epoch 141/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.7626e-04
# Epoch 142/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.6345e-04
# Epoch 143/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7059e-04
# Epoch 144/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7348e-04
# Epoch 145/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7994e-04
# Epoch 146/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7143e-04
# Epoch 147/150
# 46/46 [==============================] - 0s 4ms/step - loss: 6.5055e-04
# Epoch 148/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6219e-04
# Epoch 149/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.4696e-04
# Epoch 150/150
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6079e-04
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
# Create a DataFrame for plotting
plot_data = pd.DataFrame({
    'Date': np.concatenate((df.index[seq_length:seq_length+len(train_predict)],
                            df.index[seq_length+len(train_predict):seq_length+len(train_predict)+len(test_predict)])),
    'Predicted CPI': np.concatenate((train_predict.flatten(), test_predict.flatten())),
    'Actual CPI': np.concatenate((y_train.flatten(), y_test.flatten()))
})
# Ensure 'Date' is in datetime format
plot_data['Date'] = pd.to_datetime(plot_data['Date'])

# Shift the dates for the test predictions forward by one month
# This is done for the part of the DataFrame that contains test data
plot_data.loc[len(train_predict):, 'Date'] += pd.DateOffset(months=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# Ensure 'Date' is in datetime format
plot_data['Date'] = pd.to_datetime(plot_data['Date'])

# Create traces for Actual and Predicted CPI
trace1 = go.Scatter(x=plot_data['Date'], y=plot_data['Actual CPI'], mode='lines', name='Actual CPI')
trace2 = go.Scatter(x=plot_data['Date'], y=plot_data['Predicted CPI'], mode='lines', name='Predicted CPI')

# Layout with range selector buttons and range slider
layout = go.Layout(
    title='CPI Forecasting with LSTM',
    xaxis=dict(
        title='Date',
        rangeselector=dict(
            buttons=list([
                dict(count=1, label='1m', step='month', stepmode='backward'),
                dict(count=6, label='6m', step='month', stepmode='backward'),
                dict(count=1, label='YTD', step='year', stepmode='todate'),
                dict(count=1, label='1y', step='year', stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(visible=True),
        type='date'
    ),
    yaxis=dict(
        title='CPI'
    )
)

# Create figure and add traces
fig = go.Figure(data=[trace1, trace2], layout=layout)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a99e1caf-a06d-43d6-abcf-6f3b12684222" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a99e1caf-a06d-43d6-abcf-6f3b12684222")) {                    Plotly.newPlot(                        "a99e1caf-a06d-43d6-abcf-6f3b12684222",                        [{"mode":"lines","name":"Actual CPI","x":["1948-02-01T00:00:00","1948-03-01T00:00:00","1948-04-01T00:00:00","1948-05-01T00:00:00","1948-06-01T00:00:00","1948-07-01T00:00:00","1948-08-01T00:00:00","1948-09-01T00:00:00","1948-10-01T00:00:00","1948-11-01T00:00:00","1948-12-01T00:00:00","1949-01-01T00:00:00","1949-02-01T00:00:00","1949-03-01T00:00:00","1949-04-01T00:00:00","1949-05-01T00:00:00","1949-06-01T00:00:00","1949-07-01T00:00:00","1949-08-01T00:00:00","1949-09-01T00:00:00","1949-10-01T00:00:00","1949-11-01T00:00:00","1949-12-01T00:00:00","1950-01-01T00:00:00","1950-02-01T00:00:00","1950-03-01T00:00:00","1950-04-01T00:00:00","1950-05-01T00:00:00","1950-06-01T00:00:00","1950-07-01T00:00:00","1950-08-01T00:00:00","1950-09-01T00:00:00","1950-10-01T00:00:00","1950-11-01T00:00:00","1950-12-01T00:00:00","1951-01-01T00:00:00","1951-02-01T00:00:00","1951-03-01T00:00:00","1951-04-01T00:00:00","1951-05-01T00:00:00","1951-06-01T00:00:00","1951-07-01T00:00:00","1951-08-01T00:00:00","1951-09-01T00:00:00","1951-10-01T00:00:00","1951-11-01T00:00:00","1951-12-01T00:00:00","1952-01-01T00:00:00","1952-02-01T00:00:00","1952-03-01T00:00:00","1952-04-01T00:00:00","1952-05-01T00:00:00","1952-06-01T00:00:00","1952-07-01T00:00:00","1952-08-01T00:00:00","1952-09-01T00:00:00","1952-10-01T00:00:00","1952-11-01T00:00:00","1952-12-01T00:00:00","1953-01-01T00:00:00","1953-02-01T00:00:00","1953-03-01T00:00:00","1953-04-01T00:00:00","1953-05-01T00:00:00","1953-06-01T00:00:00","1953-07-01T00:00:00","1953-08-01T00:00:00","1953-09-01T00:00:00","1953-10-01T00:00:00","1953-11-01T00:00:00","1953-12-01T00:00:00","1954-01-01T00:00:00","1954-02-01T00:00:00","1954-03-01T00:00:00","1954-04-01T00:00:00","1954-05-01T00:00:00","1954-06-01T00:00:00","1954-07-01T00:00:00","1954-08-01T00:00:00","1954-09-01T00:00:00","1954-10-01T00:00:00","1954-11-01T00:00:00","1954-12-01T00:00:00","1955-01-01T00:00:00","1955-02-01T00:00:00","1955-03-01T00:00:00","1955-04-01T00:00:00","1955-05-01T00:00:00","1955-06-01T00:00:00","1955-07-01T00:00:00","1955-08-01T00:00:00","1955-09-01T00:00:00","1955-10-01T00:00:00","1955-11-01T00:00:00","1955-12-01T00:00:00","1956-01-01T00:00:00","1956-02-01T00:00:00","1956-03-01T00:00:00","1956-04-01T00:00:00","1956-05-01T00:00:00","1956-06-01T00:00:00","1956-07-01T00:00:00","1956-08-01T00:00:00","1956-09-01T00:00:00","1956-10-01T00:00:00","1956-11-01T00:00:00","1956-12-01T00:00:00","1957-01-01T00:00:00","1957-02-01T00:00:00","1957-03-01T00:00:00","1957-04-01T00:00:00","1957-05-01T00:00:00","1957-06-01T00:00:00","1957-07-01T00:00:00","1957-08-01T00:00:00","1957-09-01T00:00:00","1957-10-01T00:00:00","1957-11-01T00:00:00","1957-12-01T00:00:00","1958-01-01T00:00:00","1958-02-01T00:00:00","1958-03-01T00:00:00","1958-04-01T00:00:00","1958-05-01T00:00:00","1958-06-01T00:00:00","1958-07-01T00:00:00","1958-08-01T00:00:00","1958-09-01T00:00:00","1958-10-01T00:00:00","1958-11-01T00:00:00","1958-12-01T00:00:00","1959-01-01T00:00:00","1959-02-01T00:00:00","1959-03-01T00:00:00","1959-04-01T00:00:00","1959-05-01T00:00:00","1959-06-01T00:00:00","1959-07-01T00:00:00","1959-08-01T00:00:00","1959-09-01T00:00:00","1959-10-01T00:00:00","1959-11-01T00:00:00","1959-12-01T00:00:00","1960-01-01T00:00:00","1960-02-01T00:00:00","1960-03-01T00:00:00","1960-04-01T00:00:00","1960-05-01T00:00:00","1960-06-01T00:00:00","1960-07-01T00:00:00","1960-08-01T00:00:00","1960-09-01T00:00:00","1960-10-01T00:00:00","1960-11-01T00:00:00","1960-1 ...

# %%
# Display the last 10 rows of the DataFrame
display_data = plot_data.tail(10)

# Optional: Round the CPI values for better readability
display_data['Predicted CPI'] = display_data['Predicted CPI'].round(2)
display_data['Actual CPI'] = display_data['Actual CPI'].round(2)

# Show the DataFrame
display_data
# Out:
# <ipython-input-90-2649449aefd4>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-90-2649449aefd4>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Date  Predicted CPI  Actual CPI
# 899 2023-02-01           6.20        5.99
# 900 2023-03-01           5.85        4.99
# 901 2023-04-01           4.86        4.96
# 902 2023-05-01           4.83        4.13
# 903 2023-06-01           4.01        3.09
# 904 2023-07-01           2.98        3.30
# 905 2023-08-01           3.19        3.71
# 906 2023-09-01           3.59        3.69
# 907 2023-10-01           3.57        3.23
# 908 2023-11-01           3.12        3.12

# %%
# Assuming you have already trained your model and have the scaler
# Forecasted value for the new month

# Prepare new data (here, we are using the last available data point)
new_data = df.iloc[-seq_length:]['value'].values.reshape(-1, 1)

# Scale the new data
new_data_scaled = scaler.transform(new_data)

# Reshape for LSTM input
new_data_scaled = new_data_scaled.reshape(1, seq_length, 1)

# Forecast
new_month_prediction_scaled = model.predict(new_data_scaled)

# Inverse transform the prediction
new_month_prediction = scaler.inverse_transform(new_month_prediction_scaled)

print(f"Forecasted value for the new month: {new_month_prediction[0][0]}")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Forecasted value for the new month: 3.0112686157226562
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names

# %%
import pandas as pd
import plotly.graph_objs as go

# Assuming df is your original DataFrame used for LSTM prediction with 'Date' and 'value' columns
# Assuming plot_data is your DataFrame that contains the 'Date', 'Actual CPI', and 'Predicted CPI'

# Add the forecasted value to the plot_data DataFrame
last_date = plot_data['Date'].iloc[-1]  # Get the last date from the plot data
forecast_date = last_date + pd.DateOffset(months=1)  # Forecast for the next month
forecasted_value = new_month_prediction[0][0]  # This is your forecasted value for the new month

# Append the forecasted data point to the plot_data DataFrame
forecast_data = pd.DataFrame({
    'Date': [forecast_date],
    'Predicted CPI': [forecasted_value],
    'Actual CPI': [None]  # No actual value for the forecasted date
})

# Combine with the existing plot_data DataFrame
plot_data = pd.concat([plot_data, forecast_data], ignore_index=True)

# Create traces for Actual and Predicted CPI along with the Forecasted value
trace_actual = go.Scatter(x=plot_data['Date'], y=plot_data['Actual CPI'], mode='lines', name='Actual CPI')
trace_predicted = go.Scatter(x=plot_data['Date'], y=plot_data['Predicted CPI'], mode='lines', name='Predicted CPI')
trace_forecasted = go.Scatter(x=[forecast_date], y=[forecasted_value], mode='markers', name='Forecasted CPI', marker=dict(size=10, color='red'))

# Define the layout with range selector buttons
layout = go.Layout(
    title='CPI Forecasting with LSTM',
    xaxis=dict(
        title='Date',
        rangeselector=dict(
            buttons=list([
                dict(count=1, label='1m', step='month', stepmode='backward'),
                dict(count=6, label='6m', step='month', stepmode='backward'),
                dict(count=1, label='YTD', step='year', stepmode='todate'),
                dict(count=1, label='1y', step='year', stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(visible=True),
        type='date'
    ),
    yaxis=dict(
        title='CPI'
    )
)

# Combine the traces and layout into a figure
fig = go.Figure(data=[trace_actual, trace_predicted, trace_forecasted], layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0790dde-a842-416e-8574-b879f2de48b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0790dde-a842-416e-8574-b879f2de48b0")) {                    Plotly.newPlot(                        "c0790dde-a842-416e-8574-b879f2de48b0",                        [{"mode":"lines","name":"Actual CPI","x":["1948-02-01T00:00:00","1948-03-01T00:00:00","1948-04-01T00:00:00","1948-05-01T00:00:00","1948-06-01T00:00:00","1948-07-01T00:00:00","1948-08-01T00:00:00","1948-09-01T00:00:00","1948-10-01T00:00:00","1948-11-01T00:00:00","1948-12-01T00:00:00","1949-01-01T00:00:00","1949-02-01T00:00:00","1949-03-01T00:00:00","1949-04-01T00:00:00","1949-05-01T00:00:00","1949-06-01T00:00:00","1949-07-01T00:00:00","1949-08-01T00:00:00","1949-09-01T00:00:00","1949-10-01T00:00:00","1949-11-01T00:00:00","1949-12-01T00:00:00","1950-01-01T00:00:00","1950-02-01T00:00:00","1950-03-01T00:00:00","1950-04-01T00:00:00","1950-05-01T00:00:00","1950-06-01T00:00:00","1950-07-01T00:00:00","1950-08-01T00:00:00","1950-09-01T00:00:00","1950-10-01T00:00:00","1950-11-01T00:00:00","1950-12-01T00:00:00","1951-01-01T00:00:00","1951-02-01T00:00:00","1951-03-01T00:00:00","1951-04-01T00:00:00","1951-05-01T00:00:00","1951-06-01T00:00:00","1951-07-01T00:00:00","1951-08-01T00:00:00","1951-09-01T00:00:00","1951-10-01T00:00:00","1951-11-01T00:00:00","1951-12-01T00:00:00","1952-01-01T00:00:00","1952-02-01T00:00:00","1952-03-01T00:00:00","1952-04-01T00:00:00","1952-05-01T00:00:00","1952-06-01T00:00:00","1952-07-01T00:00:00","1952-08-01T00:00:00","1952-09-01T00:00:00","1952-10-01T00:00:00","1952-11-01T00:00:00","1952-12-01T00:00:00","1953-01-01T00:00:00","1953-02-01T00:00:00","1953-03-01T00:00:00","1953-04-01T00:00:00","1953-05-01T00:00:00","1953-06-01T00:00:00","1953-07-01T00:00:00","1953-08-01T00:00:00","1953-09-01T00:00:00","1953-10-01T00:00:00","1953-11-01T00:00:00","1953-12-01T00:00:00","1954-01-01T00:00:00","1954-02-01T00:00:00","1954-03-01T00:00:00","1954-04-01T00:00:00","1954-05-01T00:00:00","1954-06-01T00:00:00","1954-07-01T00:00:00","1954-08-01T00:00:00","1954-09-01T00:00:00","1954-10-01T00:00:00","1954-11-01T00:00:00","1954-12-01T00:00:00","1955-01-01T00:00:00","1955-02-01T00:00:00","1955-03-01T00:00:00","1955-04-01T00:00:00","1955-05-01T00:00:00","1955-06-01T00:00:00","1955-07-01T00:00:00","1955-08-01T00:00:00","1955-09-01T00:00:00","1955-10-01T00:00:00","1955-11-01T00:00:00","1955-12-01T00:00:00","1956-01-01T00:00:00","1956-02-01T00:00:00","1956-03-01T00:00:00","1956-04-01T00:00:00","1956-05-01T00:00:00","1956-06-01T00:00:00","1956-07-01T00:00:00","1956-08-01T00:00:00","1956-09-01T00:00:00","1956-10-01T00:00:00","1956-11-01T00:00:00","1956-12-01T00:00:00","1957-01-01T00:00:00","1957-02-01T00:00:00","1957-03-01T00:00:00","1957-04-01T00:00:00","1957-05-01T00:00:00","1957-06-01T00:00:00","1957-07-01T00:00:00","1957-08-01T00:00:00","1957-09-01T00:00:00","1957-10-01T00:00:00","1957-11-01T00:00:00","1957-12-01T00:00:00","1958-01-01T00:00:00","1958-02-01T00:00:00","1958-03-01T00:00:00","1958-04-01T00:00:00","1958-05-01T00:00:00","1958-06-01T00:00:00","1958-07-01T00:00:00","1958-08-01T00:00:00","1958-09-01T00:00:00","1958-10-01T00:00:00","1958-11-01T00:00:00","1958-12-01T00:00:00","1959-01-01T00:00:00","1959-02-01T00:00:00","1959-03-01T00:00:00","1959-04-01T00:00:00","1959-05-01T00:00:00","1959-06-01T00:00:00","1959-07-01T00:00:00","1959-08-01T00:00:00","1959-09-01T00:00:00","1959-10-01T00:00:00","1959-11-01T00:00:00","1959-12-01T00:00:00","1960-01-01T00:00:00","1960-02-01T00:00:00","1960-03-01T00:00:00","1960-04-01T00:00:00","1960-05-01T00:00:00","1960-06-01T00:00:00","1960-07-01T00:00:00","1960-08-01T00:00:00","1960-09-01T00:00:00","1960-10-01T00:00:00","1960-11-01T00:00:00","1960-1 ...

# %%
# Assuming your model and scaler are already defined and trained
# Forecasted value for the new 3 months:

# Number of months to forecast
months_to_forecast = 5

# Start with the last available sequence
new_data = df.iloc[-seq_length:]['value'].values.reshape(-1, 1)

# Scale the initial sequence
new_data_scaled = scaler.transform(new_data)

# Iteratively forecast the next months
for _ in range(months_to_forecast):
    # Reshape for LSTM input
    lstm_input = new_data_scaled.reshape(1, seq_length, 1)

    # Forecast the next month
    next_month_prediction_scaled = model.predict(lstm_input)

    # Append the prediction for the next iteration
    new_data_scaled = np.append(new_data_scaled, next_month_prediction_scaled)[-seq_length:]

    # Inverse transform the prediction
    next_month_prediction = scaler.inverse_transform(next_month_prediction_scaled.reshape(-1, 1))

    print(f"Forecasted value for the next month: {next_month_prediction[0][0]}")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
# Forecasted value for the next month: 3.0112686157226562
# 1/1 [==============================] - 0s 33ms/step
# Forecasted value for the next month: 2.9044153690338135
# 1/1 [==============================] - 0s 38ms/step
# Forecasted value for the next month: 2.799450635910034
# 1/1 [==============================] - 0s 33ms/step
# Forecasted value for the next month: 2.696382522583008
# 1/1 [==============================] - 0s 34ms/step
# Forecasted value for the next month: 2.595219373703003

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go

# Assume model, scaler, and df are predefined

# Number of months to forecast
months_to_forecast = 5

# Start with the last available sequence
new_data = df.iloc[-seq_length:]['value'].values.reshape(-1, 1)
new_data_scaled = scaler.transform(new_data)

# Store forecasted values and their corresponding dates and confidence intervals
forecast_dates = []
forecast_values = []
lower_bounds = []
upper_bounds = []

last_known_date = pd.to_datetime(df['Date'].iloc[-1])


for i in range(months_to_forecast):
    # Reshape for LSTM input
    lstm_input = new_data_scaled.reshape(1, seq_length, 1)

    # Forecast the next month
    next_month_prediction_scaled = model.predict(lstm_input)

    # Append the prediction for the next iteration
    new_data_scaled = np.append(new_data_scaled, next_month_prediction_scaled)[-seq_length:]

    # Inverse transform the prediction
    next_month_prediction = scaler.inverse_transform(next_month_prediction_scaled.reshape(-1, 1))

    # Calculate the date for the forecasted value
    forecast_date = last_known_date + pd.DateOffset(months=i + 1)
    forecast_dates.append(forecast_date)
    forecast_values.append(next_month_prediction[0][0])

    # Calculate confidence intervals
    lower_bound = next_month_prediction[0][0] - z_score * std_residuals
    upper_bound = next_month_prediction[0][0] + z_score * std_residuals
    lower_bounds.append(lower_bound)
    upper_bounds.append(upper_bound)

# Append the forecasted data to the plot_data DataFrame
forecast_df = pd.DataFrame({
    'Date': forecast_dates,
    'Predicted CPI': forecast_values,
    'Actual CPI': [None] * months_to_forecast,
    'Lower Bound CI': lower_bounds,
    'Upper Bound CI': upper_bounds
})

# Combine with the existing plot_data DataFrame
plot_data_extended = pd.concat([plot_data, forecast_df], ignore_index=True)

# Ensure 'Date' is in datetime format
plot_data_extended['Date'] = pd.to_datetime(plot_data_extended['Date'])

# Create traces for Actual CPI, Predicted CPI, and Confidence Intervals
trace_actual = go.Scatter(x=plot_data_extended['Date'], y=plot_data_extended['Actual CPI'], mode='lines', name='Actual CPI')
trace_predicted = go.Scatter(x=plot_data_extended['Date'], y=plot_data_extended['Predicted CPI'], mode='lines', name='Predicted CPI')
trace_ci_lower = go.Scatter(x=forecast_df['Date'], y=forecast_df['Lower Bound CI'], mode='lines', line=dict(width=0), showlegend=False)
trace_ci_upper = go.Scatter(x=forecast_df['Date'], y=forecast_df['Upper Bound CI'], mode='lines', fill='tonexty', fillcolor='rgba(173, 216, 230, 0.5)', line=dict(width=0), showlegend=False)

# Define the layout with range selector buttons
layout = go.Layout(
    title='CPI Forecasting with LSTM',
    xaxis=dict(
        title='Date',
        rangeselector=dict(
            buttons=list([
                dict(count=1, label='1m', step='month', stepmode='backward'),
                dict(count=6, label='6m', step='month', stepmode='backward'),
                dict(count=1, label='YTD', step='year', stepmode='todate'),
                dict(count=1, label='1y', step='year', stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(visible=True),
        type='date'
    ),
    yaxis=dict(title='CPI')
)

# Combine the traces and layout into a figure
fig = go.Figure(data=[trace_actual, trace_predicted, trace_ci_lower, trace_ci_upper], layout=layout)

# Show the figure
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-14d5c4293a18> in <cell line: 20>()
#      18 upper_bounds = []
#      19
# ---> 20 last_known_date = pd.to_datetime(df['Date'].iloc[-1])
#      21
#      22
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'
